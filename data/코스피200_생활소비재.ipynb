# %%
from pykrx import stock

# %%
tickers = stock.get_index_ticker_list(market="KOSPI")

# %%
for ticker in tickers:
    tickerName = stock.get_index_ticker_name(ticker)
    print(ticker, tickerName)
# Out:
# 1001 코스피
# 1002 코스피 대형주
# 1003 코스피 중형주
# 1004 코스피 소형주
# 1005 음식료품
# 1006 섬유의복
# 1007 종이목재
# 1008 화학
# 1009 의약품
# 1010 비금속광물
# 1011 철강금속
# 1012 기계
# 1013 전기전자
# 1014 의료정밀
# 1015 운수장비
# 1016 유통업
# 1017 전기가스업
# 1018 건설업
# 1019 운수창고업
# 1020 통신업
# 1021 금융업
# 1022
# 1024 증권
# 1025 보험
# 1026 서비스업
# 1027 제조업
# 1028 코스피 200
# 1034 코스피 100
# 1035 코스피 50
# 1150 코스피 200 커뮤니케이션서비스
# 1151 코스피 200 건설
# 1152 코스피 200 중공업
# 1153 코스피 200 철강/소재
# 1154 코스피 200 에너지/화학
# 1155 코스피 200 정보기술
# 1156 코스피 200 금융
# 1157 코스피 200 생활소비재
# 1158 코스피 200 경기소비재
# 1159 코스피 200 산업재
# 1160 코스피 200 헬스케어
# 1167 코스피 200 중소형주
# 1182 코스피 200 초대형제외 지수
# 1224 코스피 200 비중상한 30%
# 1227 코스피 200 비중상한 25%
# 1232 코스피 200 비중상한 20%
# 1244 코스피200제외 코스피지수
# 1894 코스피 200 TOP 10

# %%
df = stock.get_index_ohlcv_by_date(fromdate="20220105", todate="20221130", ticker="1157")

# %%
df
# Out:
# 코스피 200 생활소비재      시가      고가      저가      종가       거래량          거래대금  \
# 날짜
# 2022-01-05     988.83  990.39  975.80  981.33   4165387  290447786900
# 2022-01-06     977.03  986.78  976.27  979.92   4267713  311319448030
# 2022-01-07     977.72  989.29  976.36  986.98   3248111  244282930970
# 2022-01-10     970.00  971.26  944.02  955.41   4031881  620028480380
# 2022-01-11     952.85  959.43  947.16  951.46   3593909  356006875198
# ...               ...     ...     ...     ...       ...           ...
# 2022-11-24     875.22  877.36  870.13  873.67   2745520  196066078120
# 2022-11-25     876.15  881.25  869.86  877.57   3512281  214168393529
# 2022-11-28     871.24  880.06  864.65  873.22   3764755  252964906505
# 2022-11-29     873.92  894.34  872.24  891.69   4541980  321764041191
# 2022-11-30     890.00  905.60  890.00  903.26  12286700  624925241385
#
# 코스피 200 생활소비재           상장시가총액
# 날짜
# 2022-01-05      99783162811530
# 2022-01-06      99573494228200
# 2022-01-07     100310005713190
# 2022-01-10      97310925317370
# 2022-01-11      96822118865850
# ...                        ...
# 2022-11-24      89590815278720
# 2022-11-25      89951443376800
# 2022-11-28      89559940531640
# 2022-11-29      91300503098370
# 2022-11-30      92322437147150
#
# [223 rows x 7 columns]

# %%
df = df['종가'].pct_change().dropna()

# %%
df.to_csv('코스피200_생활소비재_일별.csv', encoding='utf-8-sig')
