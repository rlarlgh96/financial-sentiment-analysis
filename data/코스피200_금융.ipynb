# %%
from pykrx import stock

# %%
tickers = stock.get_index_ticker_list(market="KOSPI")

# %%
for ticker in tickers:
    tickerName = stock.get_index_ticker_name(ticker)
    print(ticker, tickerName)
# Out:
# 1001 코스피
# 1002 코스피 대형주
# 1003 코스피 중형주
# 1004 코스피 소형주
# 1005 음식료품
# 1006 섬유의복
# 1007 종이목재
# 1008 화학
# 1009 의약품
# 1010 비금속광물
# 1011 철강금속
# 1012 기계
# 1013 전기전자
# 1014 의료정밀
# 1015 운수장비
# 1016 유통업
# 1017 전기가스업
# 1018 건설업
# 1019 운수창고업
# 1020 통신업
# 1021 금융업
# 1022
# 1024 증권
# 1025 보험
# 1026 서비스업
# 1027 제조업
# 1028 코스피 200
# 1034 코스피 100
# 1035 코스피 50
# 1150 코스피 200 커뮤니케이션서비스
# 1151 코스피 200 건설
# 1152 코스피 200 중공업
# 1153 코스피 200 철강/소재
# 1154 코스피 200 에너지/화학
# 1155 코스피 200 정보기술
# 1156 코스피 200 금융
# 1157 코스피 200 생활소비재
# 1158 코스피 200 경기소비재
# 1159 코스피 200 산업재
# 1160 코스피 200 헬스케어
# 1167 코스피 200 중소형주
# 1182 코스피 200 초대형제외 지수
# 1224 코스피 200 비중상한 30%
# 1227 코스피 200 비중상한 25%
# 1232 코스피 200 비중상한 20%
# 1244 코스피200제외 코스피지수
# 1894 코스피 200 TOP 10

# %%
df = stock.get_index_ohlcv_by_date(fromdate="20220105", todate="20221130", ticker="1156")

# %%
df
# Out:
# 코스피 200 금융      시가      고가      저가      종가       거래량          거래대금  \
# 날짜
# 2022-01-05  689.75  693.39  686.61  689.88  27448307  636459101124
# 2022-01-06  689.16  693.24  683.19  685.30  20811307  529678601411
# 2022-01-07  684.48  689.57  679.54  689.46  17129754  439051067075
# 2022-01-10  690.16  707.64  690.15  706.32  39212802  942342907605
# 2022-01-11  706.70  716.49  705.99  713.63  36522919  931737911717
# ...            ...     ...     ...     ...       ...           ...
# 2022-11-24  603.08  612.72  602.76  612.56  20846262  447471212842
# 2022-11-25  612.73  615.25  608.61  611.90  18202893  372272838960
# 2022-11-28  606.71  607.52  597.92  599.37  16606590  369958439670
# 2022-11-29  599.95  618.20  598.48  616.06  19003414  468614188005
# 2022-11-30  613.11  627.42  613.11  626.83  36962315  910179635565
#
# 코스피 200 금융           상장시가총액
# 날짜
# 2022-01-05  168294699623080
# 2022-01-06  167394847048840
# 2022-01-07  168214683381890
# 2022-01-10  170444357189320
# 2022-01-11  171189412340950
# ...                     ...
# 2022-11-24  149974184778520
# 2022-11-25  150030277925320
# 2022-11-28  147184367830260
# 2022-11-29  150775123457940
# 2022-11-30  153478798879580
#
# [223 rows x 7 columns]

# %%
df = df['종가'].pct_change().dropna()

# %%
df.to_csv('코스피200_금융_일별.csv', encoding='utf-8-sig')
