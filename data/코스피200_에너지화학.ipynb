# %%
from pykrx import stock

# %%
tickers = stock.get_index_ticker_list(market="KOSPI")

# %%
for ticker in tickers:
    tickerName = stock.get_index_ticker_name(ticker)
    print(ticker, tickerName)
# Out:
# 1001 코스피
# 1002 코스피 대형주
# 1003 코스피 중형주
# 1004 코스피 소형주
# 1005 음식료품
# 1006 섬유의복
# 1007 종이목재
# 1008 화학
# 1009 의약품
# 1010 비금속광물
# 1011 철강금속
# 1012 기계
# 1013 전기전자
# 1014 의료정밀
# 1015 운수장비
# 1016 유통업
# 1017 전기가스업
# 1018 건설업
# 1019 운수창고업
# 1020 통신업
# 1021 금융업
# 1022
# 1024 증권
# 1025 보험
# 1026 서비스업
# 1027 제조업
# 1028 코스피 200
# 1034 코스피 100
# 1035 코스피 50
# 1150 코스피 200 커뮤니케이션서비스
# 1151 코스피 200 건설
# 1152 코스피 200 중공업
# 1153 코스피 200 철강/소재
# 1154 코스피 200 에너지/화학
# 1155 코스피 200 정보기술
# 1156 코스피 200 금융
# 1157 코스피 200 생활소비재
# 1158 코스피 200 경기소비재
# 1159 코스피 200 산업재
# 1160 코스피 200 헬스케어
# 1167 코스피 200 중소형주
# 1182 코스피 200 초대형제외 지수
# 1224 코스피 200 비중상한 30%
# 1227 코스피 200 비중상한 25%
# 1232 코스피 200 비중상한 20%
# 1244 코스피200제외 코스피지수
# 1894 코스피 200 TOP 10

# %%
df = stock.get_index_ohlcv_by_date(fromdate="20220105", todate="20221130", ticker="1154")

# %%
df
# Out:
# 코스피 200 에너지/화학       시가       고가       저가       종가       거래량           거래대금  \
# 날짜
# 2022-01-05      1908.22  1911.87  1888.58  1897.43   6942860  1112212449900
# 2022-01-06      1875.81  1902.13  1871.63  1885.86   6959017  1174213318884
# 2022-01-07      1901.44  1941.71  1890.74  1938.68   7528310  1382677031704
# 2022-01-10      1946.69  1953.68  1911.76  1924.79   8462879  1072970629380
# 2022-01-11      1920.41  1934.16  1881.67  1902.38   6741434  1014083687722
# ...                 ...      ...      ...      ...       ...            ...
# 2022-11-24      1661.75  1671.88  1646.98  1669.83  14329510  1178142425450
# 2022-11-25      1669.79  1686.61  1662.02  1676.80   6239244   585862837650
# 2022-11-28      1671.48  1680.88  1651.84  1660.39   6279810   542293922150
# 2022-11-29      1656.93  1678.73  1645.51  1674.36   4473943   421911405000
# 2022-11-30      1666.16  1697.85  1652.40  1696.96   9164051   909085093828
#
# 코스피 200 에너지/화학           상장시가총액
# 날짜
# 2022-01-05      171680381126350
# 2022-01-06      171636377275050
# 2022-01-07      176685034130850
# 2022-01-10      175159514705650
# 2022-01-11      174110735229350
# ...                         ...
# 2022-11-24      154329442027000
# 2022-11-25      154953852617450
# 2022-11-28      153454530150600
# 2022-11-29      154705408870750
# 2022-11-30      157075943537200
#
# [223 rows x 7 columns]

# %%
df = df['종가'].pct_change().dropna()

# %%
df.to_csv('코스피200_에너지화학_일별.csv', encoding='utf-8-sig')
