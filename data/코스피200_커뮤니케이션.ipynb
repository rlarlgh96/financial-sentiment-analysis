# %%
from pykrx import stock

# %%
tickers = stock.get_index_ticker_list(market="KOSPI")

# %%
for ticker in tickers:
    tickerName = stock.get_index_ticker_name(ticker)
    print(ticker, tickerName)
# Out:
# 1001 코스피
# 1002 코스피 대형주
# 1003 코스피 중형주
# 1004 코스피 소형주
# 1005 음식료품
# 1006 섬유의복
# 1007 종이목재
# 1008 화학
# 1009 의약품
# 1010 비금속광물
# 1011 철강금속
# 1012 기계
# 1013 전기전자
# 1014 의료정밀
# 1015 운수장비
# 1016 유통업
# 1017 전기가스업
# 1018 건설업
# 1019 운수창고업
# 1020 통신업
# 1021 금융업
# 1022
# 1024 증권
# 1025 보험
# 1026 서비스업
# 1027 제조업
# 1028 코스피 200
# 1034 코스피 100
# 1035 코스피 50
# 1150 코스피 200 커뮤니케이션서비스
# 1151 코스피 200 건설
# 1152 코스피 200 중공업
# 1153 코스피 200 철강/소재
# 1154 코스피 200 에너지/화학
# 1155 코스피 200 정보기술
# 1156 코스피 200 금융
# 1157 코스피 200 생활소비재
# 1158 코스피 200 경기소비재
# 1159 코스피 200 산업재
# 1160 코스피 200 헬스케어
# 1167 코스피 200 중소형주
# 1182 코스피 200 초대형제외 지수
# 1224 코스피 200 비중상한 30%
# 1227 코스피 200 비중상한 25%
# 1232 코스피 200 비중상한 20%
# 1244 코스피200제외 코스피지수
# 1894 코스피 200 TOP 10

# %%
df = stock.get_index_ohlcv_by_date(fromdate="20220105", todate="20221130", ticker="1150")

# %%
df
# Out:
# 코스피 200 커뮤니케이션서비스       시가       고가       저가       종가       거래량  \
# 날짜
# 2022-01-05         2971.83  2974.10  2875.51  2888.00  12026411
# 2022-01-06         2841.08  2841.54  2770.81  2776.99  13371489
# 2022-01-07         2781.77  2807.65  2771.55  2772.27   8827469
# 2022-01-10         2762.69  2762.69  2704.15  2740.08   9790280
# 2022-01-11         2736.00  2760.68  2698.76  2702.23   8983290
# ...                    ...      ...      ...      ...       ...
# 2022-11-24         1839.63  1858.76  1836.18  1850.22   5182634
# 2022-11-25         1834.26  1852.31  1822.76  1822.76   3522733
# 2022-11-28         1810.63  1812.92  1794.96  1800.63   3721540
# 2022-11-29         1795.59  1825.93  1791.55  1819.39   3431107
# 2022-11-30         1811.31  1848.55  1804.02  1848.55   8798399
#
# 코스피 200 커뮤니케이션서비스           거래대금           상장시가총액
# 날짜
# 2022-01-05         1617836885625  192809459848400
# 2022-01-06         1722792826350  184900958249600
# ...

# %%
df = df['종가'].pct_change().dropna()

# %%
df.to_csv('코스피200_커뮤니케이션_일별.csv', encoding='utf-8-sig')
