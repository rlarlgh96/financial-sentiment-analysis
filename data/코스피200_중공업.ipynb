# %%
from pykrx import stock

# %%
tickers = stock.get_index_ticker_list(market="KOSPI")

# %%
for ticker in tickers:
    tickerName = stock.get_index_ticker_name(ticker)
    print(ticker, tickerName)
# Out:
# 1001 코스피
# 1002 코스피 대형주
# 1003 코스피 중형주
# 1004 코스피 소형주
# 1005 음식료품
# 1006 섬유의복
# 1007 종이목재
# 1008 화학
# 1009 의약품
# 1010 비금속광물
# 1011 철강금속
# 1012 기계
# 1013 전기전자
# 1014 의료정밀
# 1015 운수장비
# 1016 유통업
# 1017 전기가스업
# 1018 건설업
# 1019 운수창고업
# 1020 통신업
# 1021 금융업
# 1022
# 1024 증권
# 1025 보험
# 1026 서비스업
# 1027 제조업
# 1028 코스피 200
# 1034 코스피 100
# 1035 코스피 50
# 1150 코스피 200 커뮤니케이션서비스
# 1151 코스피 200 건설
# 1152 코스피 200 중공업
# 1153 코스피 200 철강/소재
# 1154 코스피 200 에너지/화학
# 1155 코스피 200 정보기술
# 1156 코스피 200 금융
# 1157 코스피 200 생활소비재
# 1158 코스피 200 경기소비재
# 1159 코스피 200 산업재
# 1160 코스피 200 헬스케어
# 1167 코스피 200 중소형주
# 1182 코스피 200 초대형제외 지수
# 1224 코스피 200 비중상한 30%
# 1227 코스피 200 비중상한 25%
# 1232 코스피 200 비중상한 20%
# 1244 코스피200제외 코스피지수
# 1894 코스피 200 TOP 10

# %%
df = stock.get_index_ohlcv_by_date(fromdate="20220105", todate="20221130", ticker="1152")

# %%
df
# Out:
# 코스피 200 중공업      시가      고가      저가      종가       거래량          거래대금  \
# 날짜
# 2022-01-05   301.20  306.39  300.43  304.02  16237241  411159353040
# 2022-01-06   300.99  308.20  299.67  303.82  17887947  474227820610
# 2022-01-07   305.02  305.97  301.73  305.24   9797640  254094700130
# 2022-01-10   305.44  310.03  304.80  306.97  11977448  298692196110
# 2022-01-11   306.02  307.09  300.65  302.76   9486203  224691073230
# ...             ...     ...     ...     ...       ...           ...
# 2022-11-24   287.42  287.72  285.62  287.29  13479119  297549225950
# 2022-11-25   287.92  289.57  286.61  289.02  19498696  350433844790
# 2022-11-28   288.07  288.23  281.86  282.80  16023248  328191076950
# 2022-11-29   282.11  286.26  281.52  285.91  14888930  369082735080
# 2022-11-30   285.33  286.40  282.22  286.40  32069546  927093987980
#
# 코스피 200 중공업          상장시가총액
# 날짜
# 2022-01-05   56641305597540
# 2022-01-06   57030159882340
# 2022-01-07   57348720717880
# 2022-01-10   57595009367500
# 2022-01-11   56583984293140
# ...                     ...
# 2022-11-24   51676120640770
# 2022-11-25   51922617549910
# 2022-11-28   50862324242560
# 2022-11-29   51370174762730
# 2022-11-30   51571529175290
#
# [223 rows x 7 columns]

# %%
df = df['종가'].pct_change().dropna()

# %%
df.to_csv('코스피200_중공업_일별.csv', encoding='utf-8-sig')
