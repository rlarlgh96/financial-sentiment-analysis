# %%
from pykrx import stock

# %%
tickers = stock.get_index_ticker_list(market="KOSPI")

# %%
for ticker in tickers:
    tickerName = stock.get_index_ticker_name(ticker)
    print(ticker, tickerName)
# Out:
# 1001 코스피
# 1002 코스피 대형주
# 1003 코스피 중형주
# 1004 코스피 소형주
# 1005 음식료품
# 1006 섬유의복
# 1007 종이목재
# 1008 화학
# 1009 의약품
# 1010 비금속광물
# 1011 철강금속
# 1012 기계
# 1013 전기전자
# 1014 의료정밀
# 1015 운수장비
# 1016 유통업
# 1017 전기가스업
# 1018 건설업
# 1019 운수창고업
# 1020 통신업
# 1021 금융업
# 1022
# 1024 증권
# 1025 보험
# 1026 서비스업
# 1027 제조업
# 1028 코스피 200
# 1034 코스피 100
# 1035 코스피 50
# 1150 코스피 200 커뮤니케이션서비스
# 1151 코스피 200 건설
# 1152 코스피 200 중공업
# 1153 코스피 200 철강/소재
# 1154 코스피 200 에너지/화학
# 1155 코스피 200 정보기술
# 1156 코스피 200 금융
# 1157 코스피 200 생활소비재
# 1158 코스피 200 경기소비재
# 1159 코스피 200 산업재
# 1160 코스피 200 헬스케어
# 1167 코스피 200 중소형주
# 1182 코스피 200 초대형제외 지수
# 1224 코스피 200 비중상한 30%
# 1227 코스피 200 비중상한 25%
# 1232 코스피 200 비중상한 20%
# 1244 코스피200제외 코스피지수
# 1894 코스피 200 TOP 10

# %%
df = stock.get_index_ohlcv_by_date(fromdate="20220105", todate="20221130", ticker="1158")

# %%
df
# Out:
# 코스피 200 경기소비재       시가       고가       저가       종가       거래량           거래대금  \
# 날짜
# 2022-01-05     1749.87  1779.17  1747.51  1756.70  13596982  1005795582320
# 2022-01-06     1746.92  1787.12  1743.40  1767.85  11412905   942056951670
# 2022-01-07     1769.15  1788.43  1768.59  1778.99   8448249   657255760055
# 2022-01-10     1773.23  1781.54  1731.02  1734.83  10119779   719770774930
# 2022-01-11     1739.14  1750.12  1716.06  1724.85   8284049   536206789540
# ...                ...      ...      ...      ...       ...            ...
# 2022-11-24     1413.63  1415.52  1396.97  1402.01   6819144   302827345545
# 2022-11-25     1404.28  1407.14  1392.72  1395.09   5338779   250275638180
# 2022-11-28     1383.88  1397.50  1373.61  1391.62   6017840   323077830940
# 2022-11-29     1395.40  1412.91  1384.20  1410.87   8550214   381244420835
# 2022-11-30     1405.92  1429.09  1404.55  1426.92  15454820   627377092240
#
# 코스피 200 경기소비재           상장시가총액
# 날짜
# 2022-01-05     167339329180660
# 2022-01-06     168113419915365
# 2022-01-07     169172340115460
# 2022-01-10     165018547190780
# 2022-01-11     164221070594525
# ...                        ...
# 2022-11-24     138892608905860
# 2022-11-25     138099937259565
# 2022-11-28     137851428040560
# 2022-11-29     139867005528270
# 2022-11-30     141325894859640
#
# [223 rows x 7 columns]

# %%
df = df['종가'].pct_change().dropna()

# %%
df.to_csv('코스피200_경기소비재_일별.csv', encoding='utf-8-sig')
