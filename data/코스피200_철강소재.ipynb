# %%
from pykrx import stock

# %%
tickers = stock.get_index_ticker_list(market="KOSPI")

# %%
for ticker in tickers:
    tickerName = stock.get_index_ticker_name(ticker)
    print(ticker, tickerName)
# Out:
# 1001 코스피
# 1002 코스피 대형주
# 1003 코스피 중형주
# 1004 코스피 소형주
# 1005 음식료품
# 1006 섬유의복
# 1007 종이목재
# 1008 화학
# 1009 의약품
# 1010 비금속광물
# 1011 철강금속
# 1012 기계
# 1013 전기전자
# 1014 의료정밀
# 1015 운수장비
# 1016 유통업
# 1017 전기가스업
# 1018 건설업
# 1019 운수창고업
# 1020 통신업
# 1021 금융업
# 1022
# 1024 증권
# 1025 보험
# 1026 서비스업
# 1027 제조업
# 1028 코스피 200
# 1034 코스피 100
# 1035 코스피 50
# 1150 코스피 200 커뮤니케이션서비스
# 1151 코스피 200 건설
# 1152 코스피 200 중공업
# 1153 코스피 200 철강/소재
# 1154 코스피 200 에너지/화학
# 1155 코스피 200 정보기술
# 1156 코스피 200 금융
# 1157 코스피 200 생활소비재
# 1158 코스피 200 경기소비재
# 1159 코스피 200 산업재
# 1160 코스피 200 헬스케어
# 1167 코스피 200 중소형주
# 1182 코스피 200 초대형제외 지수
# 1224 코스피 200 비중상한 30%
# 1227 코스피 200 비중상한 25%
# 1232 코스피 200 비중상한 20%
# 1244 코스피200제외 코스피지수
# 1894 코스피 200 TOP 10

# %%
df = stock.get_index_ohlcv_by_date(fromdate="20220105", todate="20221130", ticker="1153")

# %%
df
# Out:
# 코스피 200 철강/소재      시가      고가      저가      종가      거래량          거래대금  \
# 날짜
# 2022-01-05     898.36  917.52  895.84  908.99  5418320  396626160500
# 2022-01-06     908.73  937.70  904.97  927.75  5609138  463965190450
# 2022-01-07     922.74  930.10  910.63  928.17  3354404  247613055850
# 2022-01-10     928.36  936.98  921.50  924.10  2588345  163611247600
# 2022-01-11     917.78  926.42  908.61  917.12  2203452  181256878600
# ...               ...     ...     ...     ...      ...           ...
# 2022-11-24     864.15  864.15  839.83  841.24  2124034  254174607730
# 2022-11-25     843.03  865.29  841.63  864.86  1831766  478365257950
# 2022-11-28     866.63  867.34  850.57  857.22  1820831  192151345390
# 2022-11-29     856.69  860.30  851.01  858.11  1123308  128502331840
# 2022-11-30     855.98  867.30  849.08  863.11  2520149  372771881681
#
# 코스피 200 철강/소재          상장시가총액
# 날짜
# 2022-01-05     47657580701950
# 2022-01-06     48750167868050
# 2022-01-07     48812203225650
# 2022-01-10     48719752573750
# 2022-01-11     48287036984500
# ...                       ...
# 2022-11-24     46944473444330
# 2022-11-25     48377068254840
# 2022-11-28     48004306140470
# 2022-11-29     47831415325390
# 2022-11-30     48316922514640
#
# [223 rows x 7 columns]

# %%
df = df['종가'].pct_change().dropna()

# %%
df.to_csv('코스피200_철강소재_일별.csv', encoding='utf-8-sig')
