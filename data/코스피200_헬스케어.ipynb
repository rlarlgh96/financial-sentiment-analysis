# %%
from pykrx import stock

# %%
tickers = stock.get_index_ticker_list(market="KOSPI")

# %%
for ticker in tickers:
    tickerName = stock.get_index_ticker_name(ticker)
    print(ticker, tickerName)
# Out:
# 1001 코스피
# 1002 코스피 대형주
# 1003 코스피 중형주
# 1004 코스피 소형주
# 1005 음식료품
# 1006 섬유의복
# 1007 종이목재
# 1008 화학
# 1009 의약품
# 1010 비금속광물
# 1011 철강금속
# 1012 기계
# 1013 전기전자
# 1014 의료정밀
# 1015 운수장비
# 1016 유통업
# 1017 전기가스업
# 1018 건설업
# 1019 운수창고업
# 1020 통신업
# 1021 금융업
# 1022
# 1024 증권
# 1025 보험
# 1026 서비스업
# 1027 제조업
# 1028 코스피 200
# 1034 코스피 100
# 1035 코스피 50
# 1150 코스피 200 커뮤니케이션서비스
# 1151 코스피 200 건설
# 1152 코스피 200 중공업
# 1153 코스피 200 철강/소재
# 1154 코스피 200 에너지/화학
# 1155 코스피 200 정보기술
# 1156 코스피 200 금융
# 1157 코스피 200 생활소비재
# 1158 코스피 200 경기소비재
# 1159 코스피 200 산업재
# 1160 코스피 200 헬스케어
# 1167 코스피 200 중소형주
# 1182 코스피 200 초대형제외 지수
# 1224 코스피 200 비중상한 30%
# 1227 코스피 200 비중상한 25%
# 1232 코스피 200 비중상한 20%
# 1244 코스피200제외 코스피지수
# 1894 코스피 200 TOP 10

# %%
df = stock.get_index_ohlcv_by_date(fromdate="20220105", todate="20221130", ticker="1160")

# %%
df
# Out:
# 코스피 200 헬스케어       시가       고가       저가       종가      거래량          거래대금  \
# 날짜
# 2022-01-05    2199.96  2200.24  2147.64  2153.27  5677153  524401520806
# 2022-01-06    2120.01  2139.37  2072.66  2076.10  5970889  587125805710
# 2022-01-07    2081.95  2127.07  2081.62  2112.25  3733612  369059683320
# 2022-01-10    2122.14  2136.37  2092.72  2106.64  3615722  381266007660
# 2022-01-11    2123.86  2155.25  2123.49  2133.46  5274959  520862297620
# ...               ...      ...      ...      ...      ...           ...
# 2022-11-24    1762.52  1773.23  1759.45  1770.97  1740015  143856732550
# 2022-11-25    1776.75  1778.76  1757.68  1759.40  1618676  136901518650
# 2022-11-28    1753.41  1753.41  1727.25  1732.70  2390393  142527760050
# 2022-11-29    1741.86  1755.24  1731.08  1750.77  1273194  110521409350
# 2022-11-30    1745.21  1765.94  1739.54  1757.72  3221190  289586959900
#
# 코스피 200 헬스케어           상장시가총액
# 날짜
# 2022-01-05    131805143272620
# 2022-01-06    127160256345750
# 2022-01-07    129168064481800
# 2022-01-10    128873937386020
# 2022-01-11    130337497897060
# ...                       ...
# 2022-11-24    122898113116500
# 2022-11-25    122744684929350
# 2022-11-28    120719574020850
# 2022-11-29    121585079266750
# 2022-11-30    121949699512100
#
# [223 rows x 7 columns]

# %%
df = df['종가'].pct_change().dropna()

# %%
df.to_csv('코스피200_헬스케어_일별.csv', encoding='utf-8-sig')
